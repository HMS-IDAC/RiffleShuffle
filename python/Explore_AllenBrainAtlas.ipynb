# %% [markdown]
# # Exploring the Allen Brain SDK
# ---
#
# This is a guide notebook to explore and download the anatomical data from the Allen Brain Institute SDK.
#
#
# ### Installation:
# If you don't have the `allensdk` package already installed, you can install it in a python (3.7) environment by using:
# `pip install allensdk`
#
# ### Resources:
# Some parts of the code present here have been extrapolated from these [examples](https://allensdk.readthedocs.io/en/latest/examples.html) that you can reference for further clarification.

# %% [markdown]
# ## Constructing a StructureTree
#
# A StructureTree object is a wrapper around a structure graph - a list of dictionaries documenting brain structures and their containment relationships. To build a structure tree, you will first need to obtain a structure graph. The `ReferenceSpaceCache` takes care of that for you.
#
# For a list of atlases and corresponding structure graph ids, see [here](http://help.brain-map.org/display/api/Atlas+Drawings+and+Ontologies).

# %%
from allensdk.core.reference_space_cache import ReferenceSpaceCache

# -------------------------------------------
reference_space_key = 'annotation/ccf_2017'
resolution = 25
# -------------------------------------------

# Create a reference space object
rspc = ReferenceSpaceCache(resolution, reference_space_key, manifest='manifest.json')
# ID 1 is the adult mouse structure graph
tree = rspc.get_structure_tree(structure_graph_id=1)

# %% [markdown]
# The fields contained in a StructureTree are:
#
# * **acronym**: a shortened name for the structure
# * **rgb_triplet**: each structure is assigned a consistent color for visualizations
# * **graph_id**: the structure graph to which this structure belongs
# * **graph_order**: each structure is assigned a consistent position in the flattened graph
# * **id**: a unique integer identifier
# * **name**: the full name of the structure
# * **structure_id_path**: traces a path from the root node (id: 997) of the tree to this structure
# * **structure_set_ids**: the structure belongs to these predefined groups

# %% [markdown]
# ## Exploring structure sets
#
# As a convenience, structures are grouped in to named collections called structure sets.
# These sets can be used to quickly gather a useful subset of structures from the tree. The criteria used to define structure sets are eclectic.
#
# A structure set might list:
#
# * structures that were used in a particular project.
# * structures that coarsely partition the brain.
# * structures that bear functional similarity.
# * something else entirely.
#
# To see only structure sets relevant to the adult mouse brain, use the StructureTree and the Ontologies API:

# %%
from allensdk.api.queries.ontologies_api import OntologiesApi

# ----------------------------------------------------------
# Import useful libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
pd.set_option('display.max_rows', 500)
# ----------------------------------------------------------

oapi = OntologiesApi()

# get the ids of all the structure sets in the tree
structure_set_ids = tree.get_structure_sets()
# query the API for information on those structure sets
s = pd.DataFrame(oapi.get_structure_sets(structure_set_ids))

# Add the number of structures contained in that specific set to the dataframe
numel = []
for sId in s['id']:
    n = len(tree.get_structures_by_set_id([sId]))
    numel.append(n)
s['structContained'] = numel

# Display the dataframe of structure sets
s
# Out:
#                                           description         id  \
# 0             List of structures in Isocortex layer 5  667481446
# 1            List of structures in Isocortex layer 6b  667481450
# 2                Summary structures of the cerebellum  688152368
# 3      List of structures for ABA Differential Search         12
# 4   List of valid structures for projection target...  184527634
# 5   Structures whose surfaces are represented by a...  691663206
# 6                  Summary structures of the midbrain  688152365
# 7                   Summary structures of the medulla  688152367
# 8                  Summary structures of the striatum  688152361
# 9   Structures representing subdivisions of the mo...  687527945
# 10    Summary structures of the hippocampal formation  688152359
# 11  List of visual cortex structures targeted for ...  514166994
# 12          Summary structures of the olfactory areas  688152358
# 13  Curated list of non-overlapping substructures ...  167587189
# 14            List of structures in Isocortex layer 4  667481445
# 15  Structures representing the major divisions of...  687527670
# 16                 Summary structures of the pallidum  688152362
# 17  List of Primary injection structures for BDA/A...  114512892
# 18  List of primary AND secondary injection struct...  112905813
# 19   List of structures for ABA Fine Structure Search         10
# 20  List of primary AND secondary injection struct...  112905828
# 21           List of structures in Isocortex layer 6a  667481449
# 22  List of structures representing a areal level ...          3
# 23            List of structures in Isocortex layer 1  667481440
# 24             Summary structures of the hypothalamus  688152364
# 25          List of structures in Isocortex layer 2/3  667481441
# 26                 All mouse visual areas with layers  396673091
# 27        Summary structures of the cortical subplate  688152360
# 28                 Summary structures of the thalamus  688152363
# 29  List of structures representing a coarse level...          2
# 30                Summary structures of the isocortex  688152357
# 31  List of Primary injection structures for Proje...  114512891
# 32                     Summary structures of the pons  688152366
#
#                                                  name  structContained
# 0                                   Isocortex layer 5               43
# 1                                  Isocortex layer 6b               43
# 2                                          Cerebellum               18
# 3                           ABA - Differential Search              843
# 4                  Mouse Connectivity - Target Search              840
# 5                      Mouse Brain - Has Surface Mesh              840
# 6                                            Midbrain               39
# 7                                             Medulla               45
# 8                                            Striatum               14
# 9                        Mouse Connectivity - Summary              293
# 10                              Hippocampal Formation               15
# 11     Allen Brain Observatory targeted structure set                7
# 12                                    Olfactory Areas               11
# 13                         Brain – Summary Structures              316
# 14                                  Isocortex layer 4               26
# 15                            Brain - Major Divisions               12
# 16                                           Pallidum                9
# 17  Mouse Connectivity - BDA/AAV Primary Injection...               79
# 18  Mouse Connectivity - BDA/AAV All Injection Str...              111
# 19                        ABA - Fine Structure Search               74
# 20  Mouse Connectivity - Projection All Injection ...              397
# 21                                 Isocortex layer 6a               43
# 22                                      Mouse - Areas               51
# 23                                  Isocortex layer 1               43
# 24                                       Hypothalamus               44
# 25                                Isocortex layer 2/3               43
# 26                      Mouse Cell Types - Structures               70
# 27                                  Cortical Subplate                7
# 28                                           Thalamus               44
# 29                                     Mouse - Coarse               12
# 30                                          Isocortex               43
# 31  Mouse Connectivity - Projection Primary Inject...              303
# 32                                               Pons               26

# %% [markdown]
# ## Take a look at an interesting Set
#
# For alignment of immunihistochemistry sections to the Allen Brain CCF (Common Coordinate Framework), the structure set **167587189** is the most suitable.
# It contains a list of brain structures for the entire brain at a **mid-ontology** level.
# This means that it contains labels for the entire brain at a medium level of detail. For example physiologically distinct cortical areas are uniquely divided, but single cortical layers are not subdivided.

# %%
chosenID = 167587189

structureList = tree.get_structures_by_set_id([chosenID])
pd.DataFrame(structureList)
# Out:
#           acronym  graph_id  graph_order         id  \
# 0             FRP         1            6        184
# 1             MOp         1           18        985
# 2             MOs         1           24        993
# 3           SSp-n         1           44        353
# 4         SSp-bfd         1           51        329
# 5          SSp-ll         1           65        337
# 6           SSp-m         1           72        345
# 7          SSp-ul         1           79        369
# 8          SSp-tr         1           86        361
# 9          SSp-un         1           93  182305689
# 10            SSs         1          100        378
# 11             GU         1          107       1057
# 12           VISC         1          114        677
# 13           AUDd         1          122       1011
# 14           AUDp         1          136       1002
# 15          AUDpo         1          143       1027
# 16           AUDv         1          150       1018
# 17          VISal         1          164        402
# 18          VISam         1          171        394
# 19           VISl         1          178        409
# 20           VISp         1          185        385
# 21          VISpl         1          192        425
# 22          VISpm         1          199        533
# 23          VISli         1          206  312782574
# 24         VISpor         1          213  312782628
# 25           ACAd         1          226         39
# 26           ACAv         1          232         48
# 27             PL         1          238        972
# 28            ILA         1          245         44
# 29           ORBl         1          258        723
# 30           ORBm         1          264        731
# 31          ORBvl         1          272        746
# 32            AId         1          279        104
# 33            AIp         1          285        111
# 34            AIv         1          291        119
# 35         RSPagl         1          298        894
# 36           RSPd         1          325        879
# 37           RSPv         1          332        886
# 38           VISa         1          346  312782546
# 39          VISrl         1          353        417
# 40            TEa         1          360        541
# 41           PERI         1          367        922
# 42            ECT         1          373        895
# 43            MOB         1          380        507
# 44            AOB         1          386        151
# 45            AON         1          390        159
# 46             TT         1          398        589
# 47             DP         1          410        814
# 48            PIR         1          416        961
# 49           NLOT         1          421        619
# 50           COAa         1          427        639
# 51           COAp         1          431        647
# 52            PAA         1          444        788
# 53             TR         1          449        566
# 54            CA1         1          457        382
# 55            CA2         1          462        423
# 56            CA3         1          467        463
# 57             DG         1          473        726
# 58             FC         1          490        982
# 59             IG         1          491         19
# 60           ENTl         1          494        918
# 61           ENTm         1          507        926
# 62            PAR         1          523        843
# 63           POST         1          527       1037
# 64            PRE         1          531       1084
# 65            SUB         1          535        502
# 66           ProS         1          544  484682470
# 67           HATA         1          553  589508447
# 68            APr         1          554  484682508
# 69            CLA         1          557        583
# 70            EPd         1          559        952
# 71            EPv         1          560        966
# 72             LA         1          561        131
# 73            BLA         1          562        295
# 74            BMA         1          566        319
# 75             PA         1          569        780
# 76             CP         1          573        672
# 77            ACB         1          575         56
# 78             FS         1          576        998
# 79             OT         1          577        754
# 80            LSc         1          587        250
# 81            LSr         1          588        258
# 82            LSv         1          589        266
# 83             SF         1          590        310
# 84             SH         1          591        333
# 85            AAA         1          593         23
# 86             BA         1          594        292
# 87            CEA         1          595        536
# 88             IA         1          599       1105
# 89            MEA         1          600        403
# 90            GPe         1          610       1022
# 91            GPi         1          611       1031
# 92             SI         1          613        342
# 93             MA         1          614        298
# 94             MS         1          617        564
# 95            NDB         1          618        596
# 96            TRS         1          619        581
# 97            BST         1          621        351
# 98            BAC         1          638        287
# 99            VAL         1          644        629
# 100            VM         1          645        685
# 101           VPL         1          647        718
# 102         VPLpc         1          648        725
# 103           VPM         1          649        733
# 104         VPMpc         1          650        741
# 105           PoT         1          651  563807435
# 106          SPFm         1          653        414
# 107          SPFp         1          654        422
# 108           SPA         1          655        609
# 109            PP         1          656       1044
# 110            MG         1          658        475
# 111           LGd         1          662        170
# 112            LP         1          668        218
# 113            PO         1          669       1020
# 114           POL         1          670       1029
# 115           SGN         1          671        325
# 116            AV         1          675        255
# 117            AM         1          676        127
# 118            AD         1          679         64
# 119           IAM         1          680       1120
# 120           IAD         1          681       1113
# 121            LD         1          682        155
# 122           IMD         1          684         59
# 123            MD         1          685        362
# 124           SMT         1          689        366
# 125            PR         1          690       1077
# 126           PVT         1          692        149
# 127            PT         1          693         15
# 128            RE         1          694        181
# 129            Xi         1          695  560581559
# 130            RH         1          697        189
# 131            CM         1          698        599
# 132           PCN         1          699        907
# 133            CL         1          700        575
# 134            PF         1          701        930
# 135           PIL         1          702  560581563
# 136            RT         1          703        262
# 137           IGL         1          705         27
# 138          IntG         1          706  563807439
# 139           LGv         1          707        178
# 140          SubG         1          710        321
# 141            MH         1          712        483
# 142            LH         1          713        186
# 143            SO         1          717        390
# 144           ASO         1          718        332
# 145           PVH         1          720         38
# 146           PVa         1          731         30
# 147           PVi         1          732        118
# 148           ARH         1          733        223
# 149           ADP         1          735         72
# 150           AVP         1          737        263
# 151          AVPV         1          738        272
# 152           DMH         1          739        830
# 153          MEPO         1          743        452
# 154           MPO         1          744        523
# 155            OV         1          745        763
# 156            PD         1          746        914
# 157            PS         1          747       1109
# 158           PVp         1          749        126
# 159          PVpo         1          750        133
# 160          SBPV         1          751        347
# 161           SCH         1          752        286
# 162           SFO         1          753        338
# 163          VMPO         1          754  576073699
# 164          VLPO         1          755        689
# 165           AHN         1          757         88
# 166            LM         1          763        210
# 167            MM         1          764        491
# 168           SUM         1          770        525
# 169           TMd         1          774       1126
# 170           TMv         1          775          1
# 171           MPN         1          776        515
# 172           PMd         1          780        980
# 173           PMv         1          781       1004
# 174          PVHd         1          782         63
# 175           VMH         1          787        693
# 176            PH         1          792        946
# 177           LHA         1          794        194
# 178           LPO         1          795        226
# 179           PST         1          796        356
# 180          PSTN         1          797        364
# 181           PeF         1          798  576073704
# 182           RCH         1          799        173
# 183           STN         1          800        470
# 184            TU         1          801        614
# 185            ZI         1          802        797
# 186            ME         1          805      10671
# 187           SCs         1          808        302
# 188            IC         1          812          4
# 189            NB         1          816        580
# 190           SAG         1          817        271
# 191           PBG         1          818        874
# 192           MEV         1          819        460
# 193           SCO         1          820  599626923
# 194           SNr         1          822        381
# 195           VTA         1          823        749
# 196            PN         1          824  607344830
# 197            RR         1          825        246
# 198           MRN         1          826        128
# 199           SCm         1          830        294
# 200           PAG         1          838        795
# 201           APN         1          844        215
# 202           MPT         1          845        531
# 203           NOT         1          846        628
# 204           NPC         1          847        634
# 205            OP         1          848        706
# 206           PPT         1          849       1061
# 207           CUN         1          852        616
# 208            RN         1          853        214
# 209           III         1          854         35
# 210           MA3         1          855  549009211
# 211            EW         1          856        975
# 212            IV         1          857        115
# 213           Pa4         1          858  606826663
# 214           VTN         1          859        757
# 215            AT         1          860        231
# 216            LT         1          861         66
# 217            DT         1          862         75
# 218            MT         1          863         58
# 219           SNc         1          866        374
# 220           PPN         1          867       1052
# 221            IF         1          869         12
# 222           IPN         1          870        100
# 223            RL         1          879        197
# 224           CLI         1          880        591
# 225            DR         1          881        872
# 226           NLL         1          885        612
# 227           PSV         1          889          7
# 228            PB         1          890        867
# 229           SOC         1          902        398
# 230             B         1          907        280
# 231           DTN         1          908        880
# 232          PDTg         1          910  599626927
# 233           PCG         1          911        898
# 234            PG         1          912        931
# 235          PRNc         1          913       1093
# 236            SG         1          915        318
# 237           SUT         1          917        534
# 238           TRN         1          918        574
# 239             V         1          919        621
# 240            P5         1          920  549009215
# 241          Acs5         1          921  549009219
# 242           PC5         1          922  549009223
# 243            I5         1          923  549009227
# 244            CS         1          925        679
# 245            LC         1          928        147
# 246           LDT         1          929        162
# 247            NI         1          930        604
# 248          PRNr         1          931        146
# 249           RPO         1          932        238
# 250           SLC         1          933        350
# 251           SLD         1          934        358
# 252            AP         1          937        207
# 253           DCO         1          941         96
# 254           VCO         1          942        101
# 255            CU         1          944        711
# 256            GR         1          945       1039
# 257           ECU         1          946        903
# 258           NTB         1          947        642
# 259           NTS         1          948        651
# 260          SPVC         1          954        429
# 261          SPVI         1          955        437
# 262          SPVO         1          956        445
# 263           Pa5         1          962  589508451
# 264            VI         1          965        653
# 265           VII         1          967        661
# 266         ACVII         1          968        576
# 267           AMB         1          970        135
# 268           DMX         1          973        839
# 269           GRN         1          975       1048
# 270           ICB         1          976        372
# 271            IO         1          977         83
# 272           IRN         1          978        136
# 273           ISN         1          979        106
# 274           LIN         1          980        203
# 275           LRN         1          981        235
# 276          MARN         1          984        307
# 277          MDRN         1          985        395
# 278         MDRNd         1          986       1098
# 279         MDRNv         1          987       1107
# 280          PARN         1          988        852
# 281           PAS         1          989        859
# 282         PGRNd         1          991        970
# 283         PGRNl         1          992        978
# 284            NR         1          995        177
# 285           PRP         1          996        169
# 286           PPY         1          998       1069
# 287           LAV         1         1002        209
# 288            MV         1         1003        202
# 289          SPIV         1         1004        225
# 290           SUV         1         1005        217
# 291             x         1         1006        765
# 292           XII         1         1007        773
# 293             y         1         1008        781
# 294            RM         1         1011        206
# 295           RPA         1         1012        230
# 296            RO         1         1013        222
# 297          LING         1         1020        912
# 298          CENT         1         1024        920
# 299           CUL         1         1033        928
# 300           DEC         1         1046        936
# 301          FOTU         1         1050        944
# 302           PYR         1         1054        951
# 303           UVU         1         1058        957
# 304           NOD         1         1062        968
# 305           SIM         1         1067       1007
# 306            AN         1         1071       1017
# 307           PRM         1         1080       1025
# 308          COPY         1         1084       1033
# 309           PFL         1         1088       1041
# 310            FL         1         1092       1049
# 311            FN         1         1097        989
# 312            IP         1         1098         91
# 313            DN         1         1099        846
# 314          VeCB         1         1100  589508455
# 315  fiber tracts         1         1101       1009
#
#                                                   name  \
# 0                        Frontal pole, cerebral cortex
# 1                                   Primary motor area
# 2                                 Secondary motor area
# 3                     Primary somatosensory area, nose
# 4             Primary somatosensory area, barrel field
# 5               Primary somatosensory area, lower limb
# 6                    Primary somatosensory area, mouth
# 7               Primary somatosensory area, upper limb
# 8                    Primary somatosensory area, trunk
# 9               Primary somatosensory area, unassigned
# 10                     Supplemental somatosensory area
# 11                                     Gustatory areas
# 12                                       Visceral area
# 13                                Dorsal auditory area
# 14                               Primary auditory area
# 15                             Posterior auditory area
# 16                               Ventral auditory area
# 17                           Anterolateral visual area
# 18                            Anteromedial visual area
# 19                                 Lateral visual area
# 20                                 Primary visual area
# 21                          Posterolateral visual area
# 22                           posteromedial visual area
# 23                             Laterointermediate area
# 24                                     Postrhinal area
# 25                Anterior cingulate area, dorsal part
# 26               Anterior cingulate area, ventral part
# 27                                      Prelimbic area
# 28                                    Infralimbic area
# 29                          Orbital area, lateral part
# 30                           Orbital area, medial part
# 31                    Orbital area, ventrolateral part
# 32                 Agranular insular area, dorsal part
# 33              Agranular insular area, posterior part
# 34                Agranular insular area, ventral part
# 35          Retrosplenial area, lateral agranular part
# 36                     Retrosplenial area, dorsal part
# 37                    Retrosplenial area, ventral part
# 38                                       Anterior area
# 39                           Rostrolateral visual area
# 40                          Temporal association areas
# 41                                     Perirhinal area
# 42                                     Ectorhinal area
# 43                                 Main olfactory bulb
# 44                            Accessory olfactory bulb
# 45                          Anterior olfactory nucleus
# 46                                        Taenia tecta
# 47                              Dorsal peduncular area
# 48                                       Piriform area
# 49              Nucleus of the lateral olfactory tract
# 50              Cortical amygdalar area, anterior part
# 51             Cortical amygdalar area, posterior part
# 52                             Piriform-amygdalar area
# 53                        Postpiriform transition area
# 54                                           Field CA1
# 55                                           Field CA2
# 56                                           Field CA3
# 57                                       Dentate gyrus
# 58                                    Fasciola cinerea
# 59                                    Induseum griseum
# 60                       Entorhinal area, lateral part
# 61           Entorhinal area, medial part, dorsal zone
# 62                                       Parasubiculum
# 63                                       Postsubiculum
# 64                                        Presubiculum
# 65                                           Subiculum
# 66                                        Prosubiculum
# 67                Hippocampo-amygdalar transition area
# 68                                     Area prostriata
# 69                                           Claustrum
# 70                   Endopiriform nucleus, dorsal part
# 71                  Endopiriform nucleus, ventral part
# 72                           Lateral amygdalar nucleus
# 73                       Basolateral amygdalar nucleus
# 74                        Basomedial amygdalar nucleus
# 75                         Posterior amygdalar nucleus
# 76                                        Caudoputamen
# 77                                   Nucleus accumbens
# 78                                  Fundus of striatum
# 79                                  Olfactory tubercle
# 80   Lateral septal nucleus, caudal (caudodorsal) part
# 81   Lateral septal nucleus, rostral (rostroventral...
# 82                Lateral septal nucleus, ventral part
# 83                               Septofimbrial nucleus
# 84                            Septohippocampal nucleus
# 85                             Anterior amygdalar area
# 86        Bed nucleus of the accessory olfactory tract
# 87                           Central amygdalar nucleus
# 88                      Intercalated amygdalar nucleus
# 89                            Medial amygdalar nucleus
# 90                   Globus pallidus, external segment
# 91                   Globus pallidus, internal segment
# 92                               Substantia innominata
# 93                               Magnocellular nucleus
# 94                               Medial septal nucleus
# 95                               Diagonal band nucleus
# 96                        Triangular nucleus of septum
# 97                  Bed nuclei of the stria terminalis
# 98              Bed nucleus of the anterior commissure
# 99    Ventral anterior-lateral complex of the thalamus
# 100             Ventral medial nucleus of the thalamus
# 101     Ventral posterolateral nucleus of the thalamus
# 266                     Accessory facial motor nucleus
# 267                                   Nucleus ambiguus
# 268            Dorsal motor nucleus of the vagus nerve
# 269                  Gigantocellular reticular nucleus
# 270                            Infracerebellar nucleus
# 271                           Inferior olivary complex
# 272                     Intermediate reticular nucleus
# 273                        Inferior salivatory nucleus
# 274                      Linear nucleus of the medulla
# 275                          Lateral reticular nucleus
# 276                    Magnocellular reticular nucleus
# 277                        Medullary reticular nucleus
# 278           Medullary reticular nucleus, dorsal part
# 279          Medullary reticular nucleus, ventral part
# 280                    Parvicellular reticular nucleus
# 281                               Parasolitary nucleus
# 282  Paragigantocellular reticular nucleus, dorsal ...
# 283  Paragigantocellular reticular nucleus, lateral...
# 284                                  Nucleus of Roller
# 285                                 Nucleus prepositus
# 286                              Parapyramidal nucleus
# 287                         Lateral vestibular nucleus
# 288                          Medial vestibular nucleus
# 289                          Spinal vestibular nucleus
# 290                        Superior vestibular nucleus
# 291                                          Nucleus x
# 292                                Hypoglossal nucleus
# 293                                          Nucleus y
# 294                               Nucleus raphe magnus
# 295                             Nucleus raphe pallidus
# 296                             Nucleus raphe obscurus
# 297                                        Lingula (I)
# 298                                     Central lobule
# 299                                             Culmen
# 300                                       Declive (VI)
# 301                          Folium-tuber vermis (VII)
# 302                                     Pyramus (VIII)
# 303                                         Uvula (IX)
# 304                                        Nodulus (X)
# 305                                      Simple lobule
# 306                                    Ansiform lobule
# 307                                  Paramedian lobule
# 308                                   Copula pyramidis
# 309                                      Paraflocculus
# 310                                          Flocculus
# 311                                  Fastigial nucleus
# 312                                 Interposed nucleus
# 313                                    Dentate nucleus
# 314                        Vestibulocerebellar nucleus
# 315                                       fiber tracts
#
#                                      structure_id_path  \
# 0                    [997, 8, 567, 688, 695, 315, 184]
# 1               [997, 8, 567, 688, 695, 315, 500, 985]
# 2               [997, 8, 567, 688, 695, 315, 500, 993]
# 3          [997, 8, 567, 688, 695, 315, 453, 322, 353]
# 4          [997, 8, 567, 688, 695, 315, 453, 322, 329]
# 5          [997, 8, 567, 688, 695, 315, 453, 322, 337]
# 6          [997, 8, 567, 688, 695, 315, 453, 322, 345]
# 7          [997, 8, 567, 688, 695, 315, 453, 322, 369]
# 8          [997, 8, 567, 688, 695, 315, 453, 322, 361]
# 9    [997, 8, 567, 688, 695, 315, 453, 322, 182305689]
# 10              [997, 8, 567, 688, 695, 315, 453, 378]
# 11                  [997, 8, 567, 688, 695, 315, 1057]
# 12                   [997, 8, 567, 688, 695, 315, 677]
# 13             [997, 8, 567, 688, 695, 315, 247, 1011]
# 14             [997, 8, 567, 688, 695, 315, 247, 1002]
# 15             [997, 8, 567, 688, 695, 315, 247, 1027]
# 16             [997, 8, 567, 688, 695, 315, 247, 1018]
# 17              [997, 8, 567, 688, 695, 315, 669, 402]
# 18              [997, 8, 567, 688, 695, 315, 669, 394]
# 19              [997, 8, 567, 688, 695, 315, 669, 409]
# 20              [997, 8, 567, 688, 695, 315, 669, 385]
# 21              [997, 8, 567, 688, 695, 315, 669, 425]
[112905828, 691663206, 687527945, 12, 68815236...  [255, 252, 145]
# 310  [112905828, 691663206, 687527945, 12, 68815236...  [255, 252, 145]
# 311  [112905828, 691663206, 687527945, 12, 68815236...  [255, 253, 188]
# 312  [112905828, 691663206, 687527945, 12, 68815236...  [255, 253, 188]
# 313  [112905828, 691663206, 687527945, 12, 68815236...  [255, 253, 188]
# 314  [112905828, 691663206, 688152368, 184527634, 1...  [255, 253, 188]
# 315       [687527945, 184527634, 167587189, 691663206]  [204, 204, 204]

# %% [markdown]
# ## Download Template and Annotation volumes
#
# You can obtain annotation volumes through the `ReferenceSpaceCache` which stores a nrrd file containing the Allen Common Coordinate Framework annotation on your hard drive. Above we set the resolution for annotations when we initialized the `ReferenceSpaceCache` to 25-micron isometric spacing. The orientation of this space is:
#
# * Anterior -> Posterior
# * Superior -> Inferior
# * Left -> Right

# %%
# Download the CCF template at the specified resolution (npArray)
template, meta_templ = rspc.get_template_volume()
# Download the CCF annotation volume at the specified resolution (npArray)
annotation, meta_annot = rspc.get_annotation_volume()

# %% [markdown]
# ## Take a look
#
# Take a look at a single slice from the **template** and the **annotation** volumes that we just downloaded.
# You can plot different coronal sections by changing the `slice_idx` parameter.

# %%
# Look at a slice from the average template and annotation volumes

# pick a slice to show
slice_idx = 300

# Utility function for plotting images better
def rescaleId(sliceImg):
    ids = np.unique(sliceImg)
    outputImg = np.copy(sliceImg)
    for i, ID in enumerate(ids):
        outputImg[outputImg==ID] = i
    return outputImg

f, ccf_axes = plt.subplots(1, 2, figsize=(17, 6))
ccf_axes[0].imshow(template[slice_idx,:,:], cmap='gray', aspect='equal', vmin=template.min(), vmax=template.max())
ccf_axes[0].set_title("Registration template")
ccf_axes[0].axis('off')

ccf_axes[1].imshow(rescaleId(annotation[slice_idx,:,:]), cmap='gray', aspect='equal')
ccf_axes[1].set_title("Annotation volume")
ccf_axes[1].axis('off')

plt.show()

# %% [markdown]
# ### Modify the annotation volume
#
# The annotation volume contains IDs for all the structures at the deepest possible ontology level.
# We are however interested in a slightly coarse areal subdivision which is provided bt setID 167587189

# %%
chosenID = 167587189
structureList = tree.get_structures_by_set_id([chosenID])

structIds = np.array([struct['id'] for struct in structureList])
annotIds = np.unique(annotation)
annotIds = annotIds[annotIds!=0]  # Removes zero

commonIds = np.intersect1d(structIds,annotIds)

print(f'The selected set (id: {chosenID}) contains {len(structIds)} structures.')
print(f'The annotation volume contains {len(annotIds)} structures.')
print(f'The two sets have {len(commonIds)} structures in common.')
# Out:
# The selected set (id: 167587189) contains 316 structures.
# The annotation volume contains 671 structures.
# The two sets have 249 structures in common.

# %% [markdown]
# ## Generate an updated annotation volume
#
# **(Long processing time)**
#
# Here we will create a copy of the annotation volume and we will curate it in order for it to contain only the ID's specified in the structureSet 167587189. To do this we will cycle thrpugh all the Id's in the annotation volume and substitute Id's that are too deep with the first ancerstor that is present in structureSet 167587189.
# Some border areas of the annotation volume have Id's of areas at a high ontology level (for example, there are many areas thoughout the brain of non-further specified *midbrain*). Since these un-assigned areas are dispersed throughout the brain and lack an ontological uniformity, we removed them by assigning Id=0.

# %%
# Copy of the whole annotation volume
updatedAnnot = np.copy(annotation)

# Utility function
any_in = lambda a, b: any(i in b for i in a)

present = 0
upstream = 0
downstream = 0
skipped = 0

# Check and update every individual id in the original annotation volume
for currId in annotIds:
    ancestors = tree.ancestor_ids([currId])[0]
    children = tree.child_ids([currId])[0]
    print(f'id:{currId}',end=' ')
    
    # If the current id is in the structure set already, skip it
    if currId in structIds:
        print(f'--  no change')
        present+=1
        continue
        
    # The current id is downstream to of one of the structures 
    # in the selected structure set
    elif any_in(ancestors,structIds):
        isMissing = True
        # get the first ancestor of the current id that's also 
        # present in the structure set
        newId = currId
        while isMissing:     
            newId = tree.parent_ids([newId])
            newId = newId[0]
            isMissing = newId not in structIds 
        updatedAnnot[updatedAnnot==currId] = newId
        print(f'--> {newId}')
        downstream+=1
        
    # The current id is upstream to of one of the structures 
    # in the selected structure set
    elif any_in(children,structIds):
        # These are portions of the brain non further annotated
        # e.g., non-annotated midbrain. Set to 0
        updatedAnnot[updatedAnnot==currId] = 0
        print(f'--> 0 (upstream) - {tree.get_structures_by_id([currId])[0]["name"]}')
        upstream+=1
        
    # Current id is in a separate tree from any structure in 
    # the selected structure set (e.g., retina, ventricular systems)
    else:
        updatedAnnot[updatedAnnot==currId] = 0
        print(f'--> 0 (different tree) - {tree.get_structures_by_id([currId])[0]["name"]}')
        skipped+=1
        

print(f'\nIds analyzed: {len(annotIds)}')
print(f'\t*present: {present} \n\t*upstream: {upstream} \n\t*downstream: {downstream} \n\t*skipped: {skipped}')
# Out:
# id:1 --  no change
# id:2 --> 345
# id:6 --> 1009
# id:7 --  no change
# id:9 --> 361
# id:10 --> 294
# id:12 --  no change
# id:15 --  no change
# id:17 --> 294
# id:19 --  no change
# id:20 --> 918
# id:23 --  no change
# id:26 --> 294
# id:27 --  no change
# id:28 --> 918
# id:30 --  no change
# id:33 --> 385
# id:35 --  no change
# id:36 --> 1057
# id:38 --  no change
# id:41 --> 533
# id:42 --> 294
# id:50 --> 795
# id:52 --> 918
# id:54 --> 1009
# id:56 --  no change
# id:58 --  no change
# id:59 --  no change
# id:62 --> 1009
# id:63 --  no change
# id:64 --  no change
# id:66 --  no change
# id:67 --> 795
# id:68 --> 184
# id:72 --  no change
# id:74 --> 409
# id:75 --  no change
# id:78 --> 1009
# id:81 --> 0 (different tree) - lateral ventricle
# id:83 --  no change
# id:84 --> 972
# id:88 --  no change
# id:91 --  no change
# id:93 --> 1009
# id:96 --  no change
# id:97 --> 541
# id:98 --> 0 (different tree) - subependymal zone
# id:100 --  no change
# id:101 --  no change
# id:102 --> 1009
# id:105 --> 398
# id:106 --  no change
# id:108 --> 0 (different tree) - choroid plexus
# id:113 --> 337
# id:114 --> 398
# id:115 --  no change
# id:117 --> 1009
# id:118 --  no change
# id:120 --> 111
# id:121 --> 409
# id:122 --> 398
# id:123 --> 867
# id:125 --> 1009
# id:126 --  no change
# id:128 --  no change
# id:129 --> 0 (different tree) - third ventricle
# id:131 --  no change
# id:132 --> 972
# id:133 --  no change
# id:136 --  no change
# id:139 --> 918
# id:140 --> 0 (different tree) - cerebral aqueduct
# id:143 --> 135
# id:145 --> 0 (different tree) - fourth ventricle
# id:146 --  no change
# id:147 --  no change
# id:148 --> 1057
# id:149 --  no change
# id:153 --> 0 (different tree) - lateral recess
# id:155 --  no change
# id:156 --> 1011
# id:158 --> 1009
# id:159 --  no change
# id:162 --  no change
# id:163 --> 111
# id:164 --> 0 (different tree) - central canal, spinal cord/medulla
# id:169 --  no change
# id:171 --> 972
# id:173 --  no change
# id:177 --  no change
# id:178 --  no change
# id:180 --> 1057
# id:181 --  no change
# id:186 --  no change
# id:187 --> 1057
# id:188 --> 151
# id:189 --  no change
# id:190 --> 1009
# id:194 --  no change
# id:196 --> 151
# id:197 --  no change
# id:198 --> 1009
# id:201 --> 329
# id:202 --  no change
# id:203 --  no change
# id:204 --> 151
# id:206 --  no change
# id:207 --  no change
# id:209 --  no change
# id:210 --  no change
# id:211 --> 39
# id:214 --  no change
# id:215 --  no change
# id:217 --  no change
# id:218 --  no change
# id:222 --  no change
# id:223 --  no change
# id:225 --  no change
# id:226 --  no change
# id:229 --> 1009
# id:230 --  no change
# id:231 --  no change
# id:233 --> 402
# id:234 --> 541
# id:237 --> 1009
# id:238 --  no change
# id:243 --> 1011
# id:246 --  no change
# id:249 --> 1027
# id:250 --  no change
# id:251 --> 1002
# id:252 --> 1011
# id:255 --  no change
# id:257 --> 533
# id:258 --  no change
# id:260 --> 619
# id:262 --  no change
# id:263 --  no change
# id:266 --  no change
# id:268 --> 619
# id:269 --> 425
# id:271 --  no change
# id:272 --  no change
# id:274 --> 879
# id:279 --> 894
# id:280 --  no change
# id:281 --> 394
# id:286 --  no change
# id:287 --  no change
# id:288 --> 746
# id:289 --> 541
# id:292 --  no change
# id:296 --> 48
# id:298 --  no change
# id:301 --> 1009
# id:303 --> 295
# id:304 --> 972
# id:305 --> 385
# id:307 --  no change
# id:310 --  no change
# id:311 --> 295
# id:313 --> 0 (different tree) - Midbrain
# id:314 --> 111
# id:318 --  no change
# id:320 --> 985
# id:321 --  no change
# id:325 --  no change
# id:326 --> 1009
# id:327 --> 319
# id:328 --> 104
# id:330 --> 879
# id:332 --  no change
# id:333 --  no change
# id:334 --> 319
# id:335 --> 922
# id:336 --> 1009
# id:338 --  no change
# id:342 --  no change
# id:344 --> 111
# id:347 --  no change
# id:349 --> 1009
# id:350 --  no change
# id:351 --  no change
# id:354 --> 0 (different tree) - Medulla
# id:355 --> 111
# id:356 --  no change
# id:358 --  no change
# id:362 --  no change
# id:363 --> 972
# id:364 --  no change
# id:366 --  no change
# id:368 --> 922
# id:372 --  no change
# id:374 --  no change
# id:377 --> 425
# id:380 --> 1009
# id:381 --  no change
# id:382 --  no change
# id:390 --  no change
# id:393 --> 425
# id:397 --> 1009
# id:401 --> 394
# id:403 --  no change
# id:412 --> 723
# id:413 --> 1009
# id:414 --  no change
# id:421 --> 409
# id:422 --  no change
# id:423 --  no change
# id:427 --> 895
# id:428 --> 1009
# id:429 --  no change
# id:430 --> 886
# id:433 --> 394
# id:434 --> 879
# id:436 --> 1009
# id:437 --  no change
# id:440 --> 723
# id:441 --> 394
# id:442 --> 879
# id:443 --> 1009
# id:445 --  no change
# id:448 --> 723
# id:449 --> 1009
# id:450 --> 369
# id:451 --> 295
# id:452 --  no change
# id:456 --> 1027
# id:460 --  no change
# id:461 --> 361
# id:463 --  no change
# id:466 --> 1009
# id:469 --> 533
# id:470 --  no change
# id:477 --> 0 (different tree) - Striatum
# id:478 --> 337
# id:482 --> 1009
# id:483 --  no change
# id:484 --> 731
# id:488 --> 723
# id:501 --> 533
# id:502 --  no change
# id:506 --> 1009
# id:507 --  no change
# id:510 --> 337
# id:512 --> 0 (different tree) - Cerebellum
# id:515 --  no change
# id:520 --> 1018
# id:523 --  no change
# id:525 --  no change
# id:526 --> 926
# id:527 --> 1011
# id:530 --> 1009
# id:531 --  no change
# id:534 --  no change
# id:538 --> 1009
# id:540 --> 922
# id:542 --> 886
# id:543 --> 926
# id:544 --> 536
# id:549 --> 0 (different tree) - Thalamus
# id:551 --> 536
# id:553 --> 1009
# id:556 --> 44
# id:558 --> 353
# id:559 --> 536
# id:564 --  no change
# id:565 --> 533
# id:566 --  no change
# id:573 --> 409
# id:574 --  no change
# id:575 --  no change
# id:576 --  no change
# id:577 --> 369
# id:579 --> 1009
# id:580 --  no change
# id:581 --  no change
# id:582 --> 731
# id:583 --  no change
# id:587 --> 795
# id:588 --> 48
# id:590 --> 886
# id:591 --  no change
# id:593 --> 385
# id:595 --> 1009
# id:596 --  no change
# id:597 --> 589
# id:598 --> 1018
# id:599 --  no change
# id:600 --> 1011
# id:601 --> 402
# id:603 --> 1009
# id:604 --  no change
# id:605 --> 589
# id:608 --> 746
# id:609 --  no change
# id:610 --> 879
# id:611 --> 1009
# id:612 --  no change
# id:613 --> 409
# id:614 --  no change
# id:616 --  no change
# id:620 --> 731
# id:621 --  no change
# id:622 --> 886
# id:625 --> 369
# id:628 --  no change
# id:629 --  no change
# id:630 --> 723
# id:632 --> 726
# id:633 --> 1009
# id:634 --  no change
# id:638 --> 1057
# id:639 --  no change
# id:642 --  no change
# id:643 --> 1027
# id:648 --> 985
# id:649 --> 402
# id:651 --  no change
# id:653 --  no change
# id:654 --> 353
# id:655 --> 647
# id:656 --> 993
# id:657 --> 345
# id:658 --> 1009
# id:661 --  no change
# id:662 --> 1057
# id:663 --> 647
# id:664 --> 926
# id:665 --> 1009
# id:667 --> 184
# id:670 --> 361
# id:671 --> 894
# id:672 --  no change
# id:673 --> 1009
# id:675 --> 119
# id:678 --> 1011
# id:679 --  no change
# id:680 --> 746
# id:681 --> 1009
# id:685 --  no change
# id:687 --> 886
# id:689 --  no change
# id:690 --> 1009
# id:692 --> 922
# id:693 --  no change
# id:694 --> 119
# id:696 --> 1027
# id:697 --> 1009
# id:698 --> 0 (upstream) - Olfactory areas
# id:699 --> 119
# id:702 --> 353
# id:703 --> 0 (upstream) - Cortical subplate
# id:704 --> 119
# id:706 --  no change
# id:707 --> 44
# id:711 --  no change
# id:718 --  no change
# id:721 --> 385
# id:725 --  no change
# id:727 --> 926
# id:728 --> 1009
# id:729 --> 541
# id:732 --> 491
# id:733 --  no change
# id:735 --> 1002
# id:741 --  no change
# id:743 --> 926
# id:744 --> 1009
# id:749 --  no change
# id:750 --> 425
# id:753 --> 1009
# id:754 --  no change
# id:755 --> 1018
# id:757 --  no change
# id:759 --> 1027
# id:763 --  no change
# id:765 --  no change
# id:767 --> 993
# id:771 --> 0 (different tree) - Pons
# id:772 --> 48
# id:773 --  no change
# id:774 --> 894
# id:778 --> 385
# id:780 --  no change
# id:781 --  no change
# id:783 --> 104
# id:784 --> 1009
# id:786 --> 541
# id:788 --  no change
# id:791 --> 1027
# id:794 --> 1009
# id:795 --  no change
# id:797 --  no change
# id:798 --> 1009
# id:800 --> 119
# id:802 --> 1009
# id:803 --> 0 (different tree) - Pallidum
# id:804 --> 797
# id:805 --> 533
# id:806 --> 378
# id:810 --> 48
# id:811 --> 4
# id:812 --> 1009
# id:814 --  no change
# id:816 --> 1002
# id:819 --> 48
# id:820 --> 4
# id:821 --> 385
# id:827 --> 44
# id:828 --> 4
# id:830 --  no change
# id:831 --> 104
# id:832 --> 1009
# id:834 --> 302
# id:836 --> 895
# id:838 --> 353
# id:839 --  no change
# id:841 --> 1009
# id:842 --> 302
# id:843 --  no change
# id:844 --> 985
# id:846 --  no change
# id:847 --> 1002
# id:848 --> 1009
# id:849 --> 677
# id:850 --> 1009
# id:851 --> 302
# id:852 --  no change
# id:854 --> 369
# id:857 --> 677
# id:859 --  no change
# id:862 --> 378
# id:863 --> 1009
# id:866 --> 1009
# id:867 --  no change
# id:869 --> 425
# id:872 --  no change
# id:873 --> 378
# id:874 --  no change
# id:878 --> 345
# id:880 --  no change
# id:882 --> 985
# id:884 --> 1009
# id:888 --> 922
# id:889 --> 353
# id:893 --> 378
# id:897 --> 677
# id:898 --  no change
# id:900 --> 1009
# id:902 --> 425
# id:903 --  no change
# id:905 --> 402
# id:906 --> 894
# id:907 --  no change
# id:908 --> 1009
# id:910 --> 731
# id:911 --> 1009
# id:912 --  no change
# id:914 --  no change
# id:916 --> 1009
# id:919 --> 39
# id:924 --> 1009
# id:927 --> 39
# id:929 --> 353
# id:930 --  no change
# id:931 --  no change
# id:935 --> 39
# id:936 --  no change
# id:939 --> 135
# id:940 --> 1009
# id:943 --> 985
# id:944 --  no change
# id:945 --> 369
# id:946 --  no change
# id:949 --> 1009
# id:950 --> 345
# id:951 --  no change
# id:952 --  no change
# id:954 --> 1002
# id:955 --> 235
# id:956 --> 1009
# id:957 --  no change
# id:959 --> 1018
# id:961 --  no change
# id:962 --> 993
# id:963 --> 235
# id:964 --> 1009
# id:965 --> 894
# id:966 --  no change
# id:968 --  no change
# id:969 --> 746
# id:970 --  no change
# id:971 --> 1009
# id:973 --> 409
# id:974 --> 345
# id:975 --  no change
# id:976 --> 920
# id:977 --> 895
# id:978 --  no change
# id:980 --  no change
# id:981 --> 329
# id:982 --  no change
# id:984 --> 920
# id:986 --> 1009
# id:988 --> 895
# id:989 --  no change
# id:990 --> 1018
# id:996 --> 104
# id:997 --> 0 (upstream) - root
# id:998 --  no change
# id:1004 --  no change
# id:1005 --> 1002
# id:1006 --> 361
# id:1007 --  no change
# id:1009 --  no change
# id:1010 --> 677
# id:1015 --> 39
# id:1016 --> 1009
# id:1020 --  no change
# id:1021 --> 993
# id:1022 --  no change
# id:1023 --> 1018
# id:1025 --  no change
# id:1026 --> 369
# id:1029 --  no change
# id:1030 --> 337
# id:1031 --  no change
# id:1033 --  no change
# id:1035 --> 378
# id:1037 --  no change
# id:1038 --> 329
# id:1039 --  no change
# id:1041 --  no change
# id:1043 --> 1009
# id:1044 --  no change
# id:1045 --> 895
# id:1046 --> 394
# id:1047 --> 329
# id:1048 --  no change
# id:1049 --  no change
# id:1051 --> 1009
# id:1052 --  no change
# id:1054 --> 44
# id:1056 --> 1017
# id:1058 --> 677
# id:1060 --> 1009
# id:1061 --  no change
# id:1062 --> 329
# id:1064 --> 1017
# id:1066 --> 394
# id:1069 --  no change
# id:1070 --> 329
# id:1072 --> 475
# id:1074 --> 402
# id:1077 --  no change
# id:1079 --> 475
# id:1081 --> 44
# id:1084 --  no change
# id:1085 --> 993
# id:1086 --> 361
# id:1088 --> 475
# id:1089 --> 0 (different tree) - Hippocampal formation
# id:1090 --> 378
# id:1091 --> 928
# id:1092 --> 1009
# id:1093 --  no change
# id:1094 --> 337
# id:1096 --> 127
# id:1097 --> 0 (upstream) - Hypothalamus
# id:1098 --  no change
# id:1101 --> 104
# id:1102 --> 345
# id:1104 --> 127
# id:1105 --  no change
# id:1106 --> 677
# id:1107 --  no change
# id:1108 --> 1009
# id:1109 --  no change
# id:1111 --> 361
# id:1113 --  no change
# id:1114 --> 402
# id:1116 --> 1009
# id:1120 --  no change
# id:1121 --> 918
# id:1123 --> 1009
# id:1125 --> 746
# id:1126 --  no change
# id:1127 --> 541
# id:1128 --> 337
# id:1139 --> 619
# id:10671 --  no change
# id:10703 --> 726
# id:10704 --> 726
# id:182305693 --> 182305689
# id:182305697 --> 182305689
# id:182305701 --> 182305689
# id:182305705 --> 182305689
# id:182305709 --> 182305689
# id:182305713 --> 182305689
# id:312782550 --> 312782546
# id:312782554 --> 312782546
# id:312782558 --> 312782546
# id:312782562 --> 312782546
# id:312782566 --> 312782546
# id:312782570 --> 312782546
# id:312782578 --> 312782574
# id:312782582 --> 312782574
# id:312782586 --> 312782574
# id:312782590 --> 312782574
# id:312782594 --> 312782574
# id:312782598 --> 312782574
# id:312782604 --> 417
# id:312782608 --> 417
# id:312782612 --> 417
# id:312782616 --> 417
# id:312782620 --> 417
# id:312782624 --> 417
# id:312782632 --> 312782628
# id:312782636 --> 312782628
# id:312782640 --> 312782628
# id:312782644 --> 312782628
# id:312782648 --> 312782628
# id:312782652 --> 312782628
# id:484682470 --  no change
# id:484682508 --  no change
# id:484682512 --> 1009
# id:484682516 --> 1009
# id:484682520 --> 1009
# id:484682524 --> 1009
# id:484682528 --> 1009
# id:496345664 --> 170
# id:496345668 --> 170
# id:496345672 --> 170
# id:526157192 --> 184
# id:526157196 --> 184
# id:526322264 --> 184
# id:527696977 --> 731
# id:549009203 --> 0 (different tree) - Retroparafascicular nucleus
# id:549009211 --  no change
# id:549009215 --  no change
# id:549009219 --  no change
# id:549009223 --  no change
# id:549009227 --  no change
# id:560581551 --> 0 (different tree) - Ethmoid nucleus of the thalamus
# id:560581559 --  no change
# id:560581563 --  no change
# id:563807435 --  no change
# id:563807439 --  no change
# id:576073699 --  no change
# id:576073704 --  no change
# id:589508447 --  no change
# id:589508451 --  no change
# id:589508455 --  no change
# id:599626923 --  no change
# id:599626927 --  no change
# id:606826647 --> 491
# id:606826651 --> 491
# id:606826655 --> 491
# id:606826659 --> 491
# id:606826663 --  no change
# id:607344830 --  no change
# id:607344834 --> 100
# id:607344838 --> 100
# id:607344842 --> 100
# id:607344846 --> 100
# id:607344850 --> 100
# id:607344854 --> 100
# id:607344858 --> 100
# id:607344862 --> 100
# id:614454277 --> 795
#
# Ids analyzed: 671
# 	*present: 249
# 	*upstream: 4
# 	*downstream: 400
# 	*skipped: 18

# %% [markdown]
# ## Take a look
#
# Take a look at a single coronal slice. The plot on the **left** if represents the original annotation volume, while on the **right** is the annotation volume resulting from the modifications that we implemented in the previous cell.
# You can plot different coronal sections by changing the `slice_idx` parameter.

# %%
# pick a slice to show
slice_idx = 280

f, ccf_axes = plt.subplots(1, 2, figsize=(15, 6))
ccf_axes[0].imshow(rescaleId(annotation[slice_idx,:,:]), cmap='gray', aspect='equal')#, vmin=0, vmax=1000)
ccf_axes[0].set_title("Original Annotation")
ccf_axes[0].axis('off')

ccf_axes[1].imshow(rescaleId(updatedAnnot[slice_idx,:,:]), cmap='gray', aspect='equal')#, vmin=0, vmax=300)
ccf_axes[1].set_title("Updated Annotations")
ccf_axes[1].axis('off')

plt.show()

# %% [markdown]
# ## Save the output files
#
# Here we save the output of this analysis that needs to be used in the rest of the riffle shuffle pipeline.
# The outputs to be saved are:
# - **Updated Annotation Volume** - The 3D annotation volume (TIFF format) containing only the Id's specified in the structureSet 167587189
# - **Id-Area map** - A .csv file containing the Id's of all the areas in the structureSet 167587189 and the respective names
# - **Template Volume** (optional) - The 3D template volume (TIFF format) of the mouse brain. A version of this template (.nrrd file) was downloaded already during the execution of this notebook, however running the optional cell will download a .tif version of the volume

# %%
# Save the Updated Annotation Volume as a .tif file
# -------------------------------------------------
from tifffile import imsave

fileName = 'UpdatedAnnotationVolume.tif'

imsave(fileName, updatedAnnot)

# %%
# Save the Id-Area map as a .csv file
# -------------------------------------------------
fileName = 'RegionIDs.csv'

# Create a dataframe
names= [tree.get_structures_by_id([areaId])[0]['name'] for areaId in structIds]
data = list(zip(structIds,names))
s = pd.DataFrame(data,columns=['id','name'])

# Save the dataframe to a .csv file
s.to_csv(fileName,index=False,header=False)

# %%
# Save the template volume volume as a .tif file
# -------------------------------------------------
from tifffile import imsave

fileName = 'template.tif'

imsave(fileName, template)
